# %% [markdown]
# # ncgb Package

# %%
LoadPackage("GBNP");
# Out:
# true

# %%
GBNP.ConfigPrint(
    "X", # 1
    "Y", # 2
    "Z"  # 3
);

# %%
nTotal := 3;;
F      := FreeAssociativeAlgebraWithOne( Rationals, nTotal );;
gens   := GeneratorsOfAlgebra(F);;
e      := gens[1];;

# %%
# Generators 𝓑(V) #
X1 := gens[2];;
X2 := gens[3];;
X3 := gens[4];;

# %%
rel1:=X1^2;
# Out:
# (1)*x.1^2

# %%
PrintNP(GP2NP(rel1));
# Out:
#  X^2

# %%
Print(GP2NP(rel1));
# Out:
# [ [ [ 1, 1 ] ], [ 1 ] ]

# %%
rel2:=X2^2;
# Out:
# (1)*x.2^2

# %%
GP2NP(rel2)[2];
# Out:
# [ 1 ]

# %%
TypeObj(GP2NP(rel2)[1]);
# Out:
# <Type: (CollectionsFamily(...), [ IsMutable, IsCopyable, IsList, ... ]), data:\ fail>

# %%
Print(GP2NP(rel2));
# Out:
# [ [ [ 2, 2 ] ], [ 1 ] ]

# %%
rel3:=X3^2;
# Out:
# (1)*x.3^2

# %%
PrintNP(GP2NP(rel3));
# Out:
#  Z^2

# %%
Print(GP2NP(rel3));
# Out:
# [ [ [ 3, 3 ] ], [ 1 ] ]

# %%
rel4 := X3*X1 + X2*X3 + X1*X2;  
rel5 := X3*X2 + X2*X1 + X1*X3;
# Out:
# (1)*x.1*x.2+(1)*x.2*x.3+(1)*x.3*x.1
# (1)*x.1*x.3+(1)*x.2*x.1+(1)*x.3*x.2

# %%
Print(GP2NP(rel4));
# Out:
# [ [ [ 3, 1 ], [ 2, 3 ], [ 1, 2 ] ], [ 1, 1, 1 ] ]

# %%
Print(GP2NP(rel5));
# Out:
# [ [ [ 3, 2 ], [ 2, 1 ], [ 1, 3 ] ], [ 1, 1, 1 ] ]

# %%
LoadPackage("ncgb");
# Out:
# true

# %% [markdown]
# Teniamos:
#
# - $g_0=xy + yz$
# - $g_1=yx + zx$
# - $G=\{g_0, g_1\}$
#
# Dijimos que:
#
# - Para $f_1=xyx - yyx$ sí vale.
# - Para $f_2=xyz + zyx$ no sabíamos.

# %%
g0 := [ [ [ 1, 1 ] ], [ 1 ] ];
g1 := [ [ [ 2, 2 ] ], [ 1 ] ];
g2 :=  [ [ [ 3, 1 ], [ 2, 3 ], [ 1, 2 ] ], [ 1, 1, 1 ] ];
g3 :=  [ [ [ 3, 2 ], [ 2, 1 ], [ 1, 3 ] ], [ 1, 1, 1 ] ];
g4 :=  [ [ [ 3, 3 ] ], [ 1 ] ];
g5 :=  [ [ [ 2, 1, 2 ], [ 1, 2, 1 ] ], [ 1, -1 ] ];
gens  := [ g0, g1 ];;
steps := 10;;
# Out:
# [ [ [ 1, 1 ] ], [ 1 ] ]
# [ [ [ 2, 2 ] ], [ 1 ] ]
# [ [ [ 3, 1 ], [ 2, 3 ], [ 1, 2 ] ], [ 1, 1, 1 ] ]
# [ [ [ 3, 2 ], [ 2, 1 ], [ 1, 3 ] ], [ 1, 1, 1 ] ]
# [ [ [ 3, 3 ] ], [ 1 ] ]
# [ [ [ 2, 1, 2 ], [ 1, 2, 1 ] ], [ 1, -1 ] ]

# %%
f1    := [ [ [ 1, 2, 1 ], [ 2, 2, 1 ] ], [ 1, -1 ] ]; #f1 := "xyx - yyx";;
g0    := [ [ [ 1, 2 ], [ 2, 3 ] ], [  1, 1 ] ];       #g0 := "xy + yz";;
g1    := [ [ [ 2, 1 ], [ 3, 1 ] ], [  1, 1 ] ];       #g1 := "yx + zx";;
gens  := [ g0, g1 ];;
steps := 10;;
# Out:
# [ [ [ 1, 2, 1 ], [ 2, 2, 1 ] ], [ 1, -1 ] ]
# [ [ [ 1, 2 ], [ 2, 3 ] ], [ 1, 1 ] ]
# [ [ [ 2, 1 ], [ 3, 1 ] ], [ 1, 1 ] ]

# %%
# InIdeal_BuchbergerCofactor(f1, gens, steps);

# %%
InIdeal_BuchbergerCofactorViaGAP(f1, gens, steps);
# Out:
# "InIdeal"

# %%
f2 := "xyz + zyx";;

# %%
InIdeal_BuchbergerCofactor(f2, gens, steps);
# Out:
# "InIdeal"

# %%
g0 := "xx";            # [ [ [ 1, 1 ] ], [ 1 ] ] 
g1 := "yy";            # [ [ [ 2, 2 ] ], [ 1 ] ]
g2 := "zx + yz + xy";  # [ [ [ 3, 1 ], [ 2, 3 ], [ 1, 2 ] ], [ 1, 1, 1 ] ]
g3 := "zy + yx + xz "; # [ [ [ 3, 2 ], [ 2, 1 ], [ 1, 3 ] ], [ 1, 1, 1 ] ]
g4 := "zz";            # [ [ [ 3, 3 ] ], [ 1 ] ]
g5 := "yxy - xyx";     # [ [ [ 2, 1, 2 ], [ 1, 2, 1 ] ], [ 1, -1 ] ]
# Out:
# "xx"
# "yy"
# "zx + yz + xy"
# "zy + yx + xz "
# "zz"
# "yxy - xyx"

# %%
Falopa4V2(gens);
# Out:
# [ "8 \n", "0 \n" ]

# %%
g0   := "xxy - 1";; 
g1   := "xyy - 1";;
gens := [g0, g1];;
Falopa4V2(gens);
# Out:
# [ "-1  + xxy\n", "-1  + xyy\n" ]

# %%
LoadPackage("ncgb");
# Out:
# true

# %%
p:=[ [ [ 1, 1 ] ], [ 1 ] ] ;
TestFalopa(p);
# Out:
# [ [ [ 1, 1 ] ], [ 1 ] ]
# [ [ [ 1, 1 ] ], [ 1 ] ]

# %%
p1 := [[[1,1,2],[]],[1,-1]];;
p2 := [[[1,2,2],[]],[1,-1]];;
PrintNPList([p1,p2]);
# Out:
#  X^2Y - 1
#  XY^2 - 1

# %%
G := SGrobner([p1,p2]);
# Out:
# [ [ [ [ 2 ], [ 1 ] ], [ 1, -1 ] ], [ [ [ 1, 1, 1 ], [  ] ], [ 1, -1 ] ] ]

# %%
PrintNPList(G);
# Out:
#  Y - X
#  X^3 - 1

# %%
Falopa4V2([p1,p2]);
# Out:
# [ "1 \n", "1 \n" ]

# %%
f1:=[ [ [ 1, 2, 1 ], [ 2, 2, 1 ] ], [ 1, -1 ] ];
# Out:
# [ [ [ 1, 2, 1 ], [ 2, 2, 1 ] ], [ 1, -1 ] ]

# %%
PrintNP(f1);
# Out:
#  XYX - Y^2X

# %%
InIdeal_BuchbergerCofactorViaGAP(f1, [p1,p2], steps);
# Out:
# "InIdeal"

# %%
p := [ [ [1,2], [3] ], [2,5] ];;

# %%
TestFalopa(p);
# Out:
# [ [ [ 3 ], [ 1, 2 ] ], [ 5, 2 ] ]

# %%
?SGrobner
# Out:
# GBNP: <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/gbnp/doc/chap3.html#X7FEDA29E78B0CEED">SGrobner</a><br/>GBNP: <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/gbnp/doc/chap3.html#X78AE6EED83B97595">SGrobnerTrace</a><br/>GBNP: <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/gbnp/doc/chap3.html#X7CD043E081BF2302">SGrobnerTrunc</a><br/>GBNP: <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/gbnp/doc/chap3.html#X860966487ED88A43">SGrobnerModule</a><br/>

# %%
PrintNPList([p1,p2]);
# Out:
#  X^2Y - 1
#  XY^2 - 1

# %%
PrintNPList(G);
# Out:
#  Y - X
#  X^3 - 1
