# %% [markdown]
# # ncgb Package

# %%
LoadPackage("ncgb");
# Out:
# true

# %% [markdown]
# Teniamos:
#
# - $g_0=xy + yz$
# - $g_1=yx + zx$
# - $G=\{g_0, g_1\}$
#
# Dijimos que:
#
# - Para $f_1=xyx - yyx$ sí vale.
# - Para $f_2=xyz + zyx$ no sabíamos.

# %%
f1 := "xyx - yyx";;
g0:="xy + yz";;
g1:="yx + zx";;
gens := [g0, g1];;
steps := 10;;

# %%
InIdeal_BuchbergerCofactor(f1, gens, steps);
# Out:
# "InIdeal"

# %%
f2:="xyz + zyx";;

# %%
InIdeal_BuchbergerCofactor(f2, gens, steps);
# Out:
# "NotInIdeal"

# %%
g0:="xx"; 
g1:="yy";
g2:="zx + yz + xy";  
g3:="zy + yx + xz "; 
g4:="zz"; 
g5:="yxy - xyx";
# Out:
# "xx"
# "yy"
# "zx + yz + xy"
# "zy + yx + xz "
# "zz"
# "yxy - xyx"

# %%
gens:=[g0, g1, g2, g3, g4, g5];
# Out:
# [ "xx", "yy", "zx + yz + xy", "zy + yx + xz ", "zz", "yxy - xyx" ]

# %%
Falopa4(gens);
# Out:
# [ "xx\n", "yy\n", "xy + yz + zx\n", "xz + yx + zy\n", "zz\n",   "-1 xyx + yxy\n" ]
