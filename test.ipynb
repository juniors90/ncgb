# %%
LoadPackage("ncgb");
# Out:
# true

# %%
ncgb_Example();
# Out:
# This is a placeholder function, replace it with your own code.

# %% [markdown]
# Esto va desde C++...

# %%
TestCommand();
# Out:
# 42

# %%
TestCommandWithParams("Hola", "Mundo");
# Out:
# "Hola"

# %%
TestCommandWithParams(2, "Mundo");
# Out:
# 2

# %%
TestCommandWithParams(["Hola"], "Mundo");
# Out:
# [ "Hola" ]

# %%
PolynomialString("x+y", 3);
# Out:
# "x+y"

# %%
ModifyPolynomialString("x + y", 3);
# Out:
# "x + y_modificado"

# %%
GetFirstPolynomial(["x + yz", "zx - yx"], 4);
# Out:
# "x + yz"

# %%
GetFirstPolynomial("x + yz", 4);
# Out:
# 'x'

# %%
GetFirstPolynomial([], 4);
# Out:
# Error, GetFirstPolynomial: La lista está vacía.
# not in any function at stream:1

# %%
GetFirstPolynomial(6, 4);
# Out:
# Error, GetFirstPolynomial: Se esperaba una lista como argumento.
# not in any function at stream:1

# %%
InIdeal_BuchbergerCofactor("xyx - yyx", ["xy + yz", "yx + zx"], 10);
# Out:
# "InIdeal"

# %%
InIdeal_BuchbergerCofactor("xyz + zyx", ["xy + yz", "yx + zx"], 10);
# Out:
# "NotInIdeal"
